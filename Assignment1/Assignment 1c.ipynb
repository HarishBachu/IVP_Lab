# %%
import numpy as np 
import cv2 
from matplotlib import pyplot as plt 

from tqdm import tqdm
from time import time

# %%
#Read images
img1= cv2.imread('/media/harish/New Volume/IVP FIles/Assignment1/input1.jpg')
img2= cv2.imread('/media/harish/New Volume/IVP FIles/Assignment1/input2.jpg')

# %%
plt.imshow(img1)
plt.show()
plt.imshow(img2)
plt.show()

# %%
def own_function(img1, img2):
    img1 = img1.astype(np.int)
    img2 = img2.astype(np.int)
    return (img1 + img2)

def for_loop(img1, img2):
    img1 = img1.astype(np.int)
    img2 = img2.astype(np.int)
    canvas = np.zeros(img1.shape)
    for k in range(img1.shape[2]):
        for i in range(img1.shape[0]):
            for j in range(img1.shape[1]):
                if img1[i][j][k] + img2[i][j][k] >= 255: 
                    canvas[i][j][k] = 255
                else:
                    canvas[i][j][k] = img1[i][j][k] + img2[i][j][k]
    canvas = canvas.astype(np.uint8)
    return canvas

# %%
plt.imshow(own_function(img1, img2))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
plt.imshow(cv2.add(img1, img2))

# %%
plt.imshow(for_loop(img1, img2))

# %%
a = np.array([255], dtype = np.uint8)
b = np.array([1], dtype = np.uint8)
print(a+b)
# Out:
# [0]

# %%
img1.shape
# Out:
# (168, 300, 3)
